# %%
# %pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (25.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install --no-cache-dir --force-reinstall "numpy==1.26.4" "pandas==2.2.2" "opencv-python-headless==4.8.1.78"
# Out:
# Collecting numpy==1.26.4
#   Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting pandas==2.2.2
#   Downloading pandas-2.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Collecting opencv-python-headless==4.8.1.78
#   Downloading opencv_python_headless-4.8.1.78-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Collecting python-dateutil>=2.8.2 (from pandas==2.2.2)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas==2.2.2)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas==2.2.2)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting six>=1.5 (from python-dateutil>=2.8.2->pandas==2.2.2)
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 209.6 MB/s  0:00:00
# Downloading pandas-2.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 210.3 MB/s  0:00:00
# Downloading opencv_python_headless-4.8.1.78-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 267.2 MB/s  0:00:00
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, six, numpy, python-dateutil, opencv-python-headless, pandas
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2025.2
#     Uninstalling pytz-2025.2:
#       Successfully uninstalled pytz-2025.2
#   Attempting uninstall: tzdata
#     Found existing installation: tzdata 2025.2
#     Uninstalling tzdata-2025.2:
#       Successfully uninstalled tzdata-2025.2
#   Attempting uninstall: six━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/7 [tzdata]
#     Found existing installation: six 1.17.0━━━━━━━━━━━━━━━━━━━ 1/7 [tzdata]
#     Uninstalling six-1.17.0:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/7 [tzdata]
#       Successfully uninstalled six-1.17.0━━━━━━━━━━━━━━━━━━━━━━━━━ 2/7 [six]
#   Attempting uninstall: numpy━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/7 [six]
#     Found existing installation: numpy 2.2.6━━━━━━━━━━━━━━━━━━ 2/7 [six]
#     Uninstalling numpy-2.2.6:╺━━━━━━━━━━━━━━━━━━━━━━ 3/7 [numpy]
#       Successfully uninstalled numpy-2.2.6━━━━━━━━━━━━━━━━━━━━ 3/7 [numpy]
#   Attempting uninstall: python-dateutil━━━━━━━━━━━━━━━━━━━━━━ 3/7 [numpy]
#     Found existing installation: python-dateutil 2.9.0.post0━━ 3/7 [numpy]
#     Uninstalling python-dateutil-2.9.0.post0:━━━━━━━━━━━━━━━━━ 3/7 [numpy]
#       Successfully uninstalled python-dateutil-2.9.0.post0━━━━ 3/7 [numpy]
#   Attempting uninstall: opencv-python-headless━━━━━━━━━━━━━━━━ 3/7 [numpy]
#     Found existing installation: opencv-python-headless 4.8.1.780m 3/7 [numpy]
#     Uninstalling opencv-python-headless-4.8.1.78:━━━━━━━━━━━━━ 3/7 [numpy]
#       Successfully uninstalled opencv-python-headless-4.8.1.78 3/7 [numpy]
#   Attempting uninstall: pandas━━━━━━╸━━━━━━━━━━━ 5/7 [opencv-python-headless]
#     Found existing installation: pandas 2.2.2m━━━━━━━━━━━ 5/7 [opencv-python-headless]
#     Uninstalling pandas-2.2.2:━━━━━━━━━━━━╺━━━━━ 6/7 [pandas]on-headless]
#       Successfully uninstalled pandas-2.2.2╺━━━━━ 6/7 [pandas]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [pandas]2m6/7 [pandas]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# azureml-mlflow 1.60.0.post1 requires azure-storage-blob<=12.19.0,>=12.5.0, but you have azure-storage-blob 12.25.1 which is incompatible.
# mlflow 3.1.1 requires mlflow-skinny==3.1.1, but you have mlflow-skinny 2.22.1 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# Successfully installed numpy-1.26.4 opencv-python-headless-4.8.1.78 pandas-2.2.2 python-dateutil-2.9.0.post0 pytz-2025.2 six-1.17.0 tzdata-2025.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install ffmpeg-python
# Out:
# Requirement already satisfied: ffmpeg-python in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (0.2.0)
# Requirement already satisfied: future in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from ffmpeg-python) (1.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install librosa soundfile
# Out:
# Requirement already satisfied: librosa in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (0.11.0)
# Requirement already satisfied: soundfile in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (0.13.1)
# Requirement already satisfied: audioread>=2.1.9 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from librosa) (3.0.1)
# Requirement already satisfied: numba>=0.51.0 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from librosa) (0.61.2)
# Requirement already satisfied: numpy>=1.22.3 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from librosa) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from librosa) (1.15.3)
# Requirement already satisfied: scikit-learn>=1.1.0 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from librosa) (1.7.0)
# Requirement already satisfied: joblib>=1.0 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from librosa) (1.5.1)
# Requirement already satisfied: decorator>=4.3.0 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from librosa) (5.2.1)
# Requirement already satisfied: pooch>=1.1 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from librosa) (0.5.0.post1)
# Requirement already satisfied: typing_extensions>=4.1.1 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from librosa) (4.14.1)
# Requirement already satisfied: lazy_loader>=0.1 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from librosa) (1.1.1)
# Requirement already satisfied: cffi>=1.0 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from soundfile) (1.17.1)
# Requirement already satisfied: pycparser in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from cffi>=1.0->soundfile) (2.22)
# Requirement already satisfied: packaging in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from lazy_loader>=0.1->librosa) (25.0)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from numba>=0.51.0->librosa) (0.44.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from pooch>=1.1->librosa) (4.3.8)
# Requirement already satisfied: requests>=2.19.0 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from pooch>=1.1->librosa) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2025.7.9)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from scikit-learn>=1.1.0->librosa) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install -q ultralytics
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mlflow 3.1.1 requires mlflow-skinny==3.1.1, but you have mlflow-skinny 2.22.1 which is incompatible.
# Note: you may need to restart the kernel to use updated packages.

# %%
# A) Weg mit cv2 & numpy (alles, was stören könnte)
# %pip uninstall -y opencv-python opencv-python-headless numpy

# B) Erst NumPy 1.x fix pinnen
# %pip install --no-cache-dir --force-reinstall "numpy==1.26.4"

# C) Dann eine cv2-Version, die sicher mit NumPy 1.26 läuft
# %pip install --no-cache-dir --force-reinstall "opencv-python-headless==4.7.0.72"

# (Optional: falls du GUI-Funktionen brauchst statt headless)
# %pip install --no-cache-dir --force-reinstall "opencv-python==4.7.0.72"
# Out:
# WARNING: Skipping opencv-python as it is not installed.
# Found existing installation: opencv-python-headless 4.7.0.72
# Uninstalling opencv-python-headless-4.7.0.72:
#   Successfully uninstalled opencv-python-headless-4.7.0.72
# Found existing installation: numpy 2.2.6
# Uninstalling numpy-2.2.6:
#   Successfully uninstalled numpy-2.2.6
# Note: you may need to restart the kernel to use updated packages.
# Collecting numpy==1.26.4
#   Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 422.4 MB/s  0:00:00
# Installing collected packages: numpy
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ultralytics 8.3.180 requires opencv-python>=4.6.0, which is not installed.
# mlflow 3.1.1 requires mlflow-skinny==3.1.1, but you have mlflow-skinny 2.22.1 which is incompatible.
# Successfully installed numpy-1.26.4
# Note: you may need to restart the kernel to use updated packages.
# Collecting opencv-python-headless==4.7.0.72
#   Downloading opencv_python_headless-4.7.0.72-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting numpy>=1.21.2 (from opencv-python-headless==4.7.0.72)
#   Downloading numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Downloading opencv_python_headless-4.7.0.72-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 MB 153.3 MB/s  0:00:00 eta 0:00:01
# Downloading numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 219.0 MB/s  0:00:00
# Installing collected packages: numpy, opencv-python-headless
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [opencv-python-headless]v-python-headless]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ultralytics 8.3.180 requires opencv-python>=4.6.0, which is not installed.
# mlflow 3.1.1 requires mlflow-skinny==3.1.1, but you have mlflow-skinny 2.22.1 which is incompatible.
# Successfully installed numpy-2.2.6 opencv-python-headless-4.7.0.72
# Note: you may need to restart the kernel to use updated packages.
# Collecting opencv-python==4.7.0.72
#   Downloading opencv_python-4.7.0.72-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting numpy>=1.21.2 (from opencv-python==4.7.0.72)
#   Downloading numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Downloading opencv_python-4.7.0.72-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (61.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.8/61.8 MB 167.0 MB/s  0:00:00 eta 0:00:01
# Downloading numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 259.5 MB/s  0:00:00
# Installing collected packages: numpy, opencv-python
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.6
#     Uninstalling numpy-2.2.6:
#       Successfully uninstalled numpy-2.2.6
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [opencv-python]0m [opencv-python]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mlflow 3.1.1 requires mlflow-skinny==3.1.1, but you have mlflow-skinny 2.22.1 which is incompatible.
# Successfully installed numpy-2.2.6 opencv-python-4.7.0.72
# Note: you may need to restart the kernel to use updated packages.

# %%
import os, math, subprocess, json
from pathlib import Path
import numpy as np
import pandas as pd

# %%
import librosa, librosa.display
import soundfile as sf
import cv2
from ultralytics import YOLO  # YOLOv8
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/anaconda/envs/azureml_py310_sdkv2/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/anaconda/envs/azureml_py310_sdkv2/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/anaconda/envs/azureml_py310_sdkv2/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/anaconda/envs/azureml_py310_sdkv2/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/anaconda/envs/azureml_py310_sdkv2/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "/anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "/anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "/anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_14008/1562235245.py", line 3, in <module>
#     import cv2
#   File "/anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/cv2/__init__.py", line 181, in <module>
#     bootstrap()
#   File "/anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/cv2/__init__.py", line 153, in bootstrap
#     native_module = importlib.import_module("cv2")
#   File "/anaconda/envs/azureml_py310_sdkv2/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found

# %%
VIDEO_PATH = Path("videos/test_video.mp4")   # dein Video
WORKDIR = Path("work_cat_poc"); WORKDIR.mkdir(exist_ok=True)
AUDIO_WAV = WORKDIR/"audio_16k_mono.wav"
FRAMES_DIR = WORKDIR/"frames"; FRAMES_DIR.mkdir(exist_ok=True)
SEGMENTS_CSV = WORKDIR/"segments.csv"

assert VIDEO_PATH.exists(), f"Video nicht gefunden: {VIDEO_PATH.resolve()}"

# %% [markdown]
# # Audio Extrahieren

# %%
import ffmpeg

_ = (
    ffmpeg
    .input(str(VIDEO_PATH))
    .output(str(AUDIO_WAV), ac=1, ar=16000, vn=None, loglevel="error")
    .overwrite_output()
    .run()
)
print("Audio extrahiert:", AUDIO_WAV.exists(), AUDIO_WAV)

# %% [markdown]
# # „Miau“-Kandidaten aus Audio (einfach & robust)
#
# Heuristik: Nicht-Stille + dominante mittlere/hohe Frequenzen → grobe Miau-Kandidaten.

# %%
y, sr = librosa.load(AUDIO_WAV, sr=16000, mono=True)

# 3a) Nicht-Stille finden
non_silent_intervals = librosa.effects.split(y, top_db=25)  # toleranter Schwellwert
intervals = []

# 3b) Frequenz-Heuristik pro Intervall (Spektral-Zentroid)
for start, end in non_silent_intervals:
    seg = y[start:end]
    if len(seg) < 0.15*sr:  # <150ms verwerfen
        continue
    S = np.abs(librosa.stft(seg, n_fft=1024, hop_length=256))
    centroid = librosa.feature.spectral_centroid(S=S, sr=sr).mean()
    # grob: "miau" häufig zwischen ~800–5000 Hz prominent
    if 800 <= centroid <= 5000:
        t0 = start/sr; t1 = end/sr
        energy = float(np.sqrt(np.mean(seg**2)))
        intervals.append({"t_start": t0, "t_end": t1, "audio_score": energy, "centroid": centroid})

audio_df = pd.DataFrame(intervals)
print("Audio-Kandidaten:", len(audio_df))
audio_df.head()

# %% [markdown]
# # „Katze im Bild“: YOLOv8-Detektion (auf sparsamen Keyframes)
#
# Wir sampeln z. B. alle 0,25 s einen Frame und prüfen, ob Klasse cat (COCO id) erkannt wird.

# %%
# Frames sampeln
cap = cv2.VideoCapture(str(VIDEO_PATH))
fps = cap.get(cv2.CAP_PROP_FPS) or 25.0
sample_every = int(max(1, round(fps * 0.25)))  # alle 0.25 s
frame_id = 0
frame_times = []
paths = []

while True:
    ret, frame = cap.read()
    if not ret:
        break
    if frame_id % sample_every == 0:
        t = frame_id / fps
        p = FRAMES_DIR / f"f_{frame_id:08d}.jpg"
        cv2.imwrite(str(p), frame)
        frame_times.append(t); paths.append(p)
    frame_id += 1

cap.release()
len(paths), "Frames extrahiert"

# %%
model = YOLO("yolov8n.pt")  # klein & schnell

cap = cv2.VideoCapture(str(VIDEO_PATH))
fps = cap.get(cv2.CAP_PROP_FPS) or 25.0
sample_every = int(max(1, round(fps * 0.25)))  # alle 0.25 s
BATCH = 64  # konservativ halten, je nach RAM/GPU

def bgr2rgb(img):
    return img[:, :, ::-1]

times_batch, frames_batch = [], []
det_rows = []

def flush_batch(times_batch, frames_batch):
    if not frames_batch:
        return
    # YOLO direkt auf Arrays → kein PIL/Dateihandle
    results = model(frames_batch, verbose=False)
    for t, r in zip(times_batch, results):
        found = False; max_conf = 0.0
        names = r.names
        for b in r.boxes:
            cls_idx = int(b.cls.item())
            conf = float(b.conf.item())
            if names[cls_idx] == "cat":
                found = True
                max_conf = max(max_conf, conf)
        det_rows.append({"t": t, "cat_present": int(found), "cat_conf": max_conf})
    times_batch.clear(); frames_batch.clear()

frame_id = 0
while True:
    ok, frame_bgr = cap.read()
    if not ok:
        break
    if frame_id % sample_every == 0:
        t = frame_id / fps
        times_batch.append(t)
        frames_batch.append(bgr2rgb(frame_bgr))  # YOLO erwartet RGB
        if len(frames_batch) >= BATCH:
            flush_batch(times_batch, frames_batch)
    frame_id += 1

cap.release()
flush_batch(times_batch, frames_batch)  # Reste

cat_df = pd.DataFrame(det_rows).sort_values("t").reset_index(drop=True)
print("Detektionspunkte:", len(cat_df))
cat_df.head()
